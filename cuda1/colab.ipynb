# %%
# !nvidia-smi

# %%
# !pip install -q pycuda numpy

# %%
# !git clone git@github.com:yarkivaev/hse-parallel-fintech-solution.git

# %%
# %cd hse-parallel-fintech-solution/cuda1

# %%
# !python main.py
